# %%
from experiment_utils import Dashboard

# %%
dashboard = Dashboard("../../.logs/")

# %%
dashboard.df()
# Out:
# <style type="text/css">
# #T_ada59 th.col_heading.level0 {
#   text-align: left;
# }
# #T_ada59 th.col_heading.level1 {
#   text-align: left;
# }
# #T_ada59 td:nth-child(1) {
#   text-align: left;
# }
# #T_ada59 td:nth-child(2) {
#   text-align: left;
# }
# </style>
# <table id="T_ada59">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ada59_level0_col0" class="col_heading level0 col0" colspan="2">meta</th>
#       <th id="T_ada59_level0_col2" class="col_heading level0 col2" colspan="4">params</th>
#       <th id="T_ada59_level0_col6" class="col_heading level0 col6" colspan="12">metrics</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_ada59_level1_col0" class="col_heading level1 col0" >experiment_id</th>
#       <th id="T_ada59_level1_col1" class="col_heading level1 col1" >experiment_name</th>
#       <th id="T_ada59_level1_col2" class="col_heading level1 col2" >param1</th>
# ...
